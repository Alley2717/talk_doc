# %%
import sounddevice as sd
from scipy.io.wavfile import write
import matplotlib.pyplot as plt
import numpy as np

def record_and_save_with_plot(filename, duration=5, samplerate=44100):
    print(f"Recording {duration} seconds of audio...")
    
    # Record audio
    audio_data = sd.rec(int(duration * samplerate), samplerate=samplerate, channels=1, dtype='int16')
    sd.wait()  # Wait for the recording to finish
    
    # Save audio to a .wav file
    write(filename, samplerate, audio_data)
    
    print(f"Audio saved as {filename}")

    # Generate and plot the waveform
    time = np.arange(0, len(audio_data)) / samplerate
    plt.figure(figsize=(10, 4))
    plt.plot(time, audio_data[:, 0], label='Channel 1')
    plt.plot(time, audio_data[:, 1], label='Channel 2')
    plt.title('Audio Waveform')
    plt.xlabel('Time (seconds)')
    plt.ylabel('Amplitude')
    plt.legend()
    plt.grid(True)
    plt.savefig('audio_waveform.png')
    plt.show()

# Example usage:
output_filename = "recorded_audio.wav"
record_and_save_with_plot(output_filename, duration=5)
# Out:
# Recording 5 seconds of audio...
# Audio saved as recorded_audio.wav
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/d8/c2k3ykr15pj9pgvb8hyzz6k00000gn/T/ipykernel_92103/3653913422.py in <module>
#      31 # Example usage:
#      32 output_filename = "recorded_audio.wav"
# ---> 33 record_and_save_with_plot(output_filename, duration=5)
#
# /var/folders/d8/c2k3ykr15pj9pgvb8hyzz6k00000gn/T/ipykernel_92103/3653913422.py in record_and_save_with_plot(filename, duration, samplerate)
#      20     plt.figure(figsize=(10, 4))
#      21     plt.plot(time, audio_data[:, 0], label='Channel 1')
# ---> 22     plt.plot(time, audio_data[:, 1], label='Channel 2')
#      23     plt.title('Audio Waveform')
#      24     plt.xlabel('Time (seconds)')
#
# IndexError: index 1 is out of bounds for axis 1 with size 1

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import matplotlib.pyplot as plt
import numpy as np

def record_and_save_with_plot(filename, duration=5, samplerate=44100):
    print(f"Recording {duration} seconds of audio...")
    
    # Record audio
    audio_data = sd.rec(int(duration * samplerate), samplerate=samplerate, channels=1, dtype='int16')
    sd.wait()  # Wait for the recording to finish
    
    # Save audio to a .wav file
    write(filename, samplerate, audio_data)
    
    print(f"Audio saved as {filename}")

    # Generate and plot the waveform
    time = np.arange(0, len(audio_data)) / samplerate
    plt.figure(figsize=(10, 4))
    plt.plot(time, audio_data[:, 0], label='Channel 1')
    plt.plot(time, audio_data[:, 1], label='Channel 2')
    plt.title('Audio Waveform')
    plt.xlabel('Time (seconds)')
    plt.ylabel('Amplitude')
    plt.legend()
    plt.grid(True)
    plt.savefig('audio_waveform2.png')
    plt.show()

# Example usage:
output_filename = "recorded_audio2.wav"
record_and_save_with_plot(output_filename, duration=5)
# Out:
# Recording 5 seconds of audio...
# Audio saved as recorded_audio2.wav
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/d8/c2k3ykr15pj9pgvb8hyzz6k00000gn/T/ipykernel_92103/3025989121.py in <module>
#      31 # Example usage:
#      32 output_filename = "recorded_audio2.wav"
# ---> 33 record_and_save_with_plot(output_filename, duration=5)
#
# /var/folders/d8/c2k3ykr15pj9pgvb8hyzz6k00000gn/T/ipykernel_92103/3025989121.py in record_and_save_with_plot(filename, duration, samplerate)
#      20     plt.figure(figsize=(10, 4))
#      21     plt.plot(time, audio_data[:, 0], label='Channel 1')
# ---> 22     plt.plot(time, audio_data[:, 1], label='Channel 2')
#      23     plt.title('Audio Waveform')
#      24     plt.xlabel('Time (seconds)')
#
# IndexError: index 1 is out of bounds for axis 1 with size 1

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import matplotlib.pyplot as plt
import numpy as np

def record_and_save_with_plot(filename, duration=5, samplerate=44100):
    print(f"Recording {duration} seconds of audio...")
    
    # Record audio
    audio_data = sd.rec(int(duration * samplerate), samplerate=samplerate, channels=1, dtype='int16')
    sd.wait()  # Wait for the recording to finish
    
    # Save audio to a .wav file
    write(filename, samplerate, audio_data)
    
    print(f"Audio saved as {filename}")

    # Generate and plot the waveform
    time = np.arange(0, len(audio_data)) / samplerate
    plt.figure(figsize=(10, 4))
    plt.plot(time, audio_data[:, 0], label='Channel 1')
    plt.plot(time, audio_data[:, 1], label='Channel 2')
    plt.title('Audio Waveform')
    plt.xlabel('Time (seconds)')
    plt.ylabel('Amplitude')
    plt.legend()
    plt.grid(True)
    plt.savefig('audio_waveform3.png')
    plt.show()

# Example usage:
output_filename = "recorded_audio3.wav"
record_and_save_with_plot(output_filename, duration=5)
# Out:
# Recording 5 seconds of audio...
# Audio saved as recorded_audio3.wav
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/d8/c2k3ykr15pj9pgvb8hyzz6k00000gn/T/ipykernel_96839/3822141954.py in <module>
#      31 # Example usage:
#      32 output_filename = "recorded_audio3.wav"
# ---> 33 record_and_save_with_plot(output_filename, duration=5)
#
# /var/folders/d8/c2k3ykr15pj9pgvb8hyzz6k00000gn/T/ipykernel_96839/3822141954.py in record_and_save_with_plot(filename, duration, samplerate)
#      20     plt.figure(figsize=(10, 4))
#      21     plt.plot(time, audio_data[:, 0], label='Channel 1')
# ---> 22     plt.plot(time, audio_data[:, 1], label='Channel 2')
#      23     plt.title('Audio Waveform')
#      24     plt.xlabel('Time (seconds)')
#
# IndexError: index 1 is out of bounds for axis 1 with size 1

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import matplotlib.pyplot as plt
import numpy as np

def record_and_save_with_plot(filename, duration=5, samplerate=44100):
    print(f"Recording {duration} seconds of audio...")
    
    # Record audio
    audio_data = sd.rec(int(duration * samplerate), samplerate=samplerate, channels=1, dtype='int16')
    sd.wait()  # Wait for the recording to finish
    
    # Save audio to a .wav file
    write(filename, samplerate, audio_data)
    
    print(f"Audio saved as {filename}")

    # Generate and plot the waveform
    time = np.arange(0, len(audio_data)) / samplerate
    plt.figure(figsize=(10, 4))
    plt.plot(time, audio_data[:, 0], label='Channel 1')
    plt.plot(time, audio_data[:, 1], label='Channel 2')
    plt.title('Audio Waveform')
    plt.xlabel('Time (seconds)')
    plt.ylabel('Amplitude')
    plt.legend()
    plt.grid(True)
    plt.savefig('audio_waveform4.png')
    plt.show()

# Example usage:
output_filename = "recorded_audio4.wav"
record_and_save_with_plot(output_filename, duration=5)
# Out:
# Recording 5 seconds of audio...
# Audio saved as recorded_audio4.wav
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/d8/c2k3ykr15pj9pgvb8hyzz6k00000gn/T/ipykernel_96839/3978350415.py in <module>
#      31 # Example usage:
#      32 output_filename = "recorded_audio4.wav"
# ---> 33 record_and_save_with_plot(output_filename, duration=5)
#
# /var/folders/d8/c2k3ykr15pj9pgvb8hyzz6k00000gn/T/ipykernel_96839/3978350415.py in record_and_save_with_plot(filename, duration, samplerate)
#      20     plt.figure(figsize=(10, 4))
#      21     plt.plot(time, audio_data[:, 0], label='Channel 1')
# ---> 22     plt.plot(time, audio_data[:, 1], label='Channel 2')
#      23     plt.title('Audio Waveform')
#      24     plt.xlabel('Time (seconds)')
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
